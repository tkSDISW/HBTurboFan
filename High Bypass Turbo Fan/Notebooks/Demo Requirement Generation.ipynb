# %% [markdown]
# # Requirement Generation of ETA Values Example
#
# Generate requirements for various component eff.

# %% [markdown]
# ### Model-Specific Code (Do Not Modify)
#
# This section contains code that is specific to the system model. It is updated only when the model is changed and should not require user modifications under normal circumstances.
#
# If a new model is introduced, ensure this section is reviewed and updated as needed.

# %%
#!pip install --upgrade git+https://github.com/tkSDISW/Capella_Tools 
import capellambse.decl

from capella_tools import capellambse_helper


from IPython import display as diag_display
resources = {
    "HBTurboFan": "HBTurbFan/High Bypass Turbo Fan",
}
path_to_model = "../High Bypass Turbo Fan.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources)

# %% [markdown]
# Load Embedding to locate the object by name.

# %%
from capella_tools  import capella_embeddings_manager

# Generate embeddings for all objects
model_embedding_manager = capella_embeddings_manager.EmbeddingManager()

embedding_file = "embeddings.json" 
model_embedding_manager.set_files( path_to_model , embedding_file)

model_embedding_manager.create_model_embeddings(model)
# Out:
# ✅ EmbeddingManager initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# Loading embeddings
# embeddings loaded.

# %% [markdown]
# Search for the component.

# %%
selected_objects = model_embedding_manager.query_and_select_top_objects("[LAB] TurboFan Mech", top_n=1)
# Out:
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: Bleed Air Valve Actuator, Similarity: 0.91, Type: LogicalComponent, Phase: Logical Architecture LA, Source: , Target:

# %% [markdown]
#  📝 Generate Structured Input File
# .

# %%
#Workflow
from capella_tools import capellambse_yaml_manager
yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects : 
    yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  



#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()

# %% [markdown]
# ## 🖼️ Generate Contextual Diagram

# %%
from capella_tools import capellambse_helper
from IPython import display as diag_display
from IPython.display import Markdown
for object in  selected_objects : 
    #print(object)
    if object["type"] == "Diagram" :
        diagram = model.by_uuid(object["uuid"])
        #display(diagram)
    else:
        obj = model.by_uuid(object["uuid"])
        capellambse_helper.display_context_diagram(obj)
# Out:
# <Diagram 'Context of Bleed Air Valve Actuator'>

# %%
prompt = """
Generate a set of functional requirements for each Blead Air Valve Actuator .
- Each requirment should be a pair: (name, body).
- The name shall be five or fewer words introducing the requirement.
- The body shall be in the format of a shall statement, that is clear and concise. 
- The  body shall refer to the the owning logical component. In format of component x shall deliver function y producing output z. Embelish the basic functions to improve readability and understanding. 
- Display name as html h1 header level.
- Display the body as a html p for paragraph.
- State sources from yaml of from general knowledge.
"""

# %%
import os
from openai import OpenAI
from IPython.core.display import HTML
from IPython.display import display, clear_output, Markdown
from capella_tools  import Open_AI_RAG_manager
  


# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()

# Step 2: Invoke ChatGPT for analysis
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(
    yaml_content=yaml_content,
    config_name="gpt-oss-120b"
)
analyzer.initial_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.siemens.com/llm/v1
# 🤖 Model: gpt-oss-120b
# **Your prompt:**
# Generate a set of functional requirements for each Blead Air Valve Actuator .
# - Each requirment should be a pair: (name, body).
# - The name shall be five or fewer words introducing the requirement.
# - The body shall be in the format of a shall statement, that is clear and concise.
# - The  body shall refer to the the owning logical component. In format of component x shall deliver function y producing output z. Embelish the basic functions to improve readability and understanding.
# - Display name as html h1 header level.
# - Display the body as a html p for paragraph.
# - State sources from yaml of from general knowledge.
#  Format the response in .html format.
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Bleed Air Valve Actuator Functional Requirements</title>
# </head>
# <body>
# <h1>Set Bleed Air Position</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the logical function <strong>Set Bleed Air Position</strong> and produce the output <strong>Bleed Air Valve Percentage</strong> (Functional Exchange UUID 5f715b20‑4600‑4a0b‑993f‑ff7e07a56328) so that downstream systems can accurately control the bleed‑air flow.
# </p>
# <p><em>Source: YAML model – LogicalFunction “Set Bleed Air Postion” (UUID d1dbfcf0‑0ddb‑4b71‑9d8b‑875678ed24b0); General aerospace control‑system knowledge.</em></p>
# <h1>Transmit Bleed‑Air Data</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the component exchange <strong>M‑Bleed Air</strong> and generate the output <strong>Bleed Air Valve Percentage</strong> (Functional Exchange UUID 5f715b20‑4600‑4a0b‑993f‑ff7e07a56328) to inform the aircraft’s bleed‑air management module of the current valve opening.
# </p>
# <p><em>Source: YAML model – ComponentExchange “M‑Bleed Air” (UUID 56fa856d‑8503‑4e0d‑a856‑b5c68b918b80); General knowledge of aircraft bleed‑air distribution.</em></p>
# <h1>Receive Control Commands</h1>
# <p>
#     The Bleed Air Valve Actuator shall accept the component exchange <strong>E‑Bleed Air</strong> and produce the input <strong>Bleed Air Position</strong> (Functional Exchange UUID fddba676‑404f‑4ad5‑b6c6‑32a72a100584) so that the actuator can act on commands issued by the flight‑control system.
# </p>
# <p><em>Source: YAML model – ComponentExchange “E‑Bleed AIr” (UUID 1b38b041‑3496‑4dd0‑9069‑49543995e5b9); General knowledge of command‑based valve actuation.</em></p>
# <h1>Expose Input Port FIP 1</h1>
# <p>
#     The Bleed Air Valve Actuator shall expose the function input port <strong>FIP 1</strong> (UUID 23fc1dd5‑92a3‑4326‑9bdb‑aefeb60a2ae8) to receive the <strong>Bleed Air Position</strong> functional exchange, enabling the actuator to synchronize its internal state with the commanded position.
# </p>
# <p><em>Source: YAML model – FunctionInputPort “FIP 1” (UUID 23fc1dd5‑92a3‑4326‑9bdb‑aefeb60a2ae8); General knowledge of input‑port handling in control loops.</em></p>
# <h1>Expose Output Port FOP 1</h1>
# <p>
#     The Bleed Air Valve Actuator shall expose the function output port <strong>FOP 1</strong> (UUID eb5e8bf6‑0698‑4da3‑8ab8‑60779f32a2fe) to deliver the <strong>Bleed Air Valve Percentage</strong> functional exchange, providing downstream components with the current valve opening percentage.
# </p>
# <p><em>Source: YAML model – FunctionOutputPort “FOP 1” (UUID eb5e8bf6‑0698‑4da3‑8ab8‑60779f32a2fe); General knowledge of output‑port semantics in functional architectures.</em></p>
# </body>
# </html>
# **Token Usage Info:**
#
# Tokens used: prompt=2212, completion=1189, total=3401

# %% [markdown]
# ## ⚙️ Execute Followup Prompts
#
# ### Purpose
# This cell executes the **follow up prompts** defined for analyzing the model. These prompts can be added by the note book user in addition to the default prompts
#
# ### What This Cell Does
# - Use the structured input file (e.g., `capella_model.yaml`).
# - Excutes the prompt defined in the cell.
# - Outputs the results directly in the notebook.
#
# ### 🛠️ Instructions
# 1. Ensure the `capella_model.yaml` file is generated and up-to-date.
# 2. Run this cell to execute the default prompts.
# 3. Review the output to verify the accuracy and relevance of the analysis.
#
# > 💡 **Tip:** Modify the promt to your needs.

# %%
prompt = """
Generate a set of performance requirements for each Blead Air Valve Actuator.
- Each requirment should be a pair: (name, body).
- The name shall be five or fewer words introducing the requirement.
- The body shall be in the format of a shall statement, that is clear and concise. 
- The  body shall refer to the the owning logical component. In format of component x shall deliver function y producing output z. Embelish the basic functions to improve readability and understanding. 
- Display name as html h1 header level.
- Display the body as a html p for paragraph.
- Display a rationale for the performance requitement.
- State sources from yaml of from general knowledge.
"""


analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# **Your prompt:**
# Generate a set of performance requirements for each Blead Air Valve Actuator.
# - Each requirment should be a pair: (name, body).
# - The name shall be five or fewer words introducing the requirement.
# - The body shall be in the format of a shall statement, that is clear and concise.
# - The  body shall refer to the the owning logical component. In format of component x shall deliver function y producing output z. Embelish the basic functions to improve readability and understanding.
# - Display name as html h1 header level.
# - Display the body as a html p for paragraph.
# - Display a rationale for the performance requitement.
# - State sources from yaml of from general knowledge.
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Bleed Air Valve Actuator – Performance Requirements</title>
# </head>
# <body>
# <h1>Fast Response Time</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the logical function <strong>Set Bleed Air Position</strong> producing the output <strong>Bleed Air Valve Percentage</strong> within <strong>0.5 seconds</strong> of receiving a command, ensuring rapid adjustment of bleed‑air flow for flight‑critical maneuvers.
# </p>
# <p><em>Rationale: Quick actuation is required to maintain aircraft performance during rapid throttle changes, climb, or descent.</em></p>
# <p><small>Source: YAML – LogicalFunction “Set Bleed Air Postion” (UUID d1dbfcf0‑0ddb‑4b71‑9d8b‑875678ed24b0); General aerospace control‑system timing guidelines.</small></p>
# <h1>Position Accuracy</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the logical function <strong>Set Bleed Air Position</strong> producing the output <strong>Bleed Air Valve Percentage</strong> with an accuracy of <strong>±2 % of full scale</strong>, guaranteeing precise regulation of bleed‑air pressure.
# </p>
# <p><em>Rationale: Accurate valve positioning prevents over‑pressurization of downstream systems and supports optimal engine performance.</em></p>
# <p><small>Source: YAML – FunctionalExchange “Bleed Air Valve Percentage” (UUID 5f715b20‑4600‑4a0b‑993f‑ff7e07a56328); Industry best‑practice for hydraulic/ pneumatic valve accuracy.</small></p>
# <h1>Output Update Rate</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the logical function <strong>Set Bleed Air Position</strong> producing the output <strong>Bleed Air Valve Percentage</strong> at a minimum update frequency of <strong>10 Hz</strong>, providing timely feedback to the aircraft’s bleed‑air management system.
# </p>
# <p><em>Rationale: A high update rate enables the flight‑control computer to monitor and adjust the valve continuously, improving stability of the bleed‑air system.</em></p>
# <p><small>Source: YAML – ComponentExchange “M‑Bleed Air” (UUID 56fa856d‑8503‑4e0d‑a856‑b5c68b918b80); General knowledge of real‑time control loops in avionics.</small></p>
# <h1>Operating Temperature Range</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the logical function <strong>Set Bleed Air Position</strong> producing the output <strong>Bleed Air Valve Percentage</strong> reliably across an ambient temperature range of <strong>‑55 °C to +85 °C</strong>.
# </p>
# <p><em>Rationale: Aircraft components must function in extreme environmental conditions encountered at high altitude and on the ground.</em></p>
# <p><small>Source: YAML – Component definition (no explicit temperature data, inferred from typical aerospace component specifications); General aerospace environmental standards.</small></p>
# <h1>Mean Time Between Failures</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the logical function <strong>Set Bleed Air Position</strong> producing the output <strong>Bleed Air Valve Percentage</strong> with a Mean Time Between Failures (MTBF) of at least <strong>30,000 hours</strong>, ensuring long‑term reliability throughout the aircraft’s service life.
# </p>
# <p><em>Rationale: High reliability reduces maintenance costs and prevents loss of bleed‑air capability during operation.</em></p>
# <p><small>Source: YAML – No explicit MTBF, derived from typical reliability targets for critical flight‑control actuators; General aerospace reliability data.</small></p>
# </body>
# </html>
# **Token Usage Info:**
#
# Tokens used: prompt=3213, completion=1074, total=4287

# %%
prompt = """
Generate a set of interface requirements for Bleed Air Valve Actuator .
- Each requirment should be a pair: (name, body).
- The name shall be five or fewer words introducing the requirement.
- The body shall be in the format of a shall statement, that is clear and concise. 
- The  body shall refer to the the owning logical component. In format of component x shall deliver function y producing output z. Embelish the basic functions to improve readability and understanding. 
- Display name as html h1 header level.
- Display the body as a html p for paragraph.
- State sources from yaml of from general knowledge.
"""


analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# **Your prompt:**
# Generate a set of interface requirements for Bleed Air Valve Actuator .
# - Each requirment should be a pair: (name, body).
# - The name shall be five or fewer words introducing the requirement.
# - The body shall be in the format of a shall statement, that is clear and concise.
# - The  body shall refer to the the owning logical component. In format of component x shall deliver function y producing output z. Embelish the basic functions to improve readability and understanding.
# - Display name as html h1 header level.
# - Display the body as a html p for paragraph.
# - State sources from yaml of from general knowledge.
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Bleed Air Valve Actuator – Interface Requirements</title>
# </head>
# <body>
# <h1>Control Command Interface</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the logical function <strong>Set Bleed Air Position</strong> producing the output <strong>Bleed Air Valve Percentage</strong> through its <strong>CP 2</strong> port, receiving command data via the <strong>E‑Bleed Air</strong> component exchange.
# </p>
# <p><small>Source: YAML – ComponentPort CP 2 (UUID 4b82fd84‑58c0‑4958‑bad5‑597418912f81) and ComponentExchange “E‑Bleed AIr” (UUID 1b38b041‑3496‑4dd0‑9069‑49543995e5b9); general avionics interface practice.</small></p>
# <h1>Telemetry Output Interface</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the logical function <strong>Set Bleed Air Position</strong> producing the output <strong>Bleed Air Valve Percentage</strong> via its <strong>CP 1</strong> port, publishing the value through the <strong>M‑Bleed Air</strong> component exchange for downstream monitoring systems.
# </p>
# <p><small>Source: YAML – ComponentPort CP 1 (UUID 3327df97‑ada5‑4059‑b8e0‑491c73456733) and ComponentExchange “M‑Bleed Air” (UUID 56fa856d‑8503‑4e0d‑a856‑b5c68b918b80); typical aircraft data‑bus conventions.</small></p>
# <h1>Functional Input Port Specification</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the logical function <strong>Set Bleed Air Position</strong> producing the output <strong>Bleed Air Valve Percentage</strong> after receiving the input <strong>Bleed Air Position</strong> on its function‑input port <strong>FIP 1</strong>.
# </p>
# <p><small>Source: YAML – FunctionInputPort “FIP 1” (UUID 23fc1dd5‑92a3‑4326‑9bdb‑aefeb60a2ae8) linked to the functional exchange “Bleed Air Position” (UUID fddba676‑404f‑4ad5‑b6c6‑32a72a100584); standard functional‑port modeling.</small></p>
# <h1>Functional Output Port Specification</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the logical function <strong>Set Bleed Air Position</strong> producing the output <strong>Bleed Air Valve Percentage</strong> on its function‑output port <strong>FOP 1</strong>, making the result available to any consumer of the “Bleed Air Valve Percentage” functional exchange.
# </p>
# <p><small>Source: YAML – FunctionOutputPort “FOP 1” (UUID eb5e8bf6‑0698‑4da3‑8ab8‑60779f32a2fe) and FunctionalExchange “Bleed Air Valve Percentage” (UUID 5f715b20‑4600‑4a0b‑993f‑ff7e07a56328); functional architecture guidelines.</small></p>
# <h1>Bidirectional Data Consistency</h1>
# <p>
#     The Bleed Air Valve Actuator shall deliver the logical function <strong>Set Bleed Air Position</strong> producing the output <strong>Bleed Air Valve Percentage</strong> while ensuring that the values exchanged on <strong>CP 1</strong> (M‑Bleed Air) and <strong>CP 2</strong> (E‑Bleed Air) remain synchronized within the same control cycle.
# </p>
# <p><small>Source: YAML – Both ports and exchanges defined under the Bleed Air Valve Actuator; general requirement for deterministic data flow in safety‑critical systems.</small></p>
# </body>
# </html>
# **Token Usage Info:**
#
# Tokens used: prompt=4216, completion=1109, total=5325

# %%
print("Done")
# Out:
# Done

# %% [markdown]
# #
