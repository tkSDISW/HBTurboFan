# %% [markdown]
# # Requirement Generation Example
#
# Bleed Air Valve Actuator Report

# %% [markdown]
# ### Model-Specific Code (Do Not Modify)
#
# This section contains code that is specific to the system model. It is updated only when the model is changed and should not require user modifications under normal circumstances.
#
# If a new model is introduced, ensure this section is reviewed and updated as needed.

# %%
#!pip install --upgrade git+https://github.com/tkSDISW/Capella_Tools 
import capellambse.decl

from capella_tools import capellambse_helper


from IPython import display as diag_display
resources = {
    "HBTurboFan": "HBTurbFan/High Bypass Turbo Fan",
}
path_to_model = "../High Bypass Turbo Fan.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources)

# %% [markdown]
# Load Embedding to locate the object by name.

# %%
from capella_tools  import capella_embeddings_manager

# Generate embeddings for all objects
model_embedding_manager = capella_embeddings_manager.EmbeddingManager()

embedding_file = "embeddings.json" 
model_embedding_manager.set_files( path_to_model , embedding_file)

model_embedding_manager.create_model_embeddings(model)
# Out:
# ✅ EmbeddingManager initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# Loading embeddings
# embeddings loaded.

# %% [markdown]
# Search for the component.

# %%
selected_objects = model_embedding_manager.query_and_select_top_objects("[LAB] TurboFan Mech", top_n=1)
# Out:
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: [LAB] TurboFan Mech, Similarity: 0.85, Type: Diagram, Phase: Logical Architecture LA, Source: , Target:

# %% [markdown]
#  📝 Generate Structured Input File
# .

# %%
#Workflow
from capella_tools import capellambse_yaml_manager
yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects : 
    yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  



#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()

# %% [markdown]
# ## 🖼️ Generate Contextual Diagram

# %%
from capella_tools import capellambse_helper
from IPython import display as diag_display
from IPython.display import Markdown
for object in  selected_objects : 
    #print(object)
    if object["type"] == "Diagram" :
        diagram = model.by_uuid(object["uuid"])
        #display(diagram)
    else:
        obj = model.by_uuid(object["uuid"])
        capellambse_helper.display_context_diagram(obj)

# %%
prompt = """
Generate a set of requirements for eta, use the attached notebook file for the values for eta for component. Use the yaml file for the names of component in the requirement. 
- Each requirment should be a pair: (name, body).
- The name shall be five or fewer words introducing the requirement.
- The body shall be in the format of a shall statement, that is clear and concise. 
- The  body shall refer to the the owning logical component. In format of component x shall deliver eta (use the greek symbol) y producing output z. Embelish the basic functions to improve readability and understanding. 
- Display name as html h1 header level.
- Display the body as a html p for paragraph.
- State sources from yaml of from general knowledge.
"""

# %%
import os
from openai import OpenAI
from IPython.core.display import HTML
from IPython.display import display, clear_output, Markdown
from capella_tools  import Open_AI_RAG_manager
  


# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()

# Step 2: Invoke ChatGPT for analysis
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(
    yaml_content=yaml_content,
    config_name="gpt-oss-120b"
)
#analyzer.add_text_file_to_messages("Demo_TwinComp_Fuel.txt")
analyzer.initial_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.siemens.com/llm/v1
# 🤖 Model: gpt-oss-120b
# **Your prompt:**
# Generate a set of requirements for eta, use the attached notebook file for the values for eta for component. Use the yaml file for the names of component in the requirement.
# - Each requirment should be a pair: (name, body).
# - The name shall be five or fewer words introducing the requirement.
# - The body shall be in the format of a shall statement, that is clear and concise.
# - The  body shall refer to the the owning logical component. In format of component x shall deliver eta (use the greek symbol) y producing output z. Embelish the basic functions to improve readability and understanding.
# - Display name as html h1 header level.
# - Display the body as a html p for paragraph.
# - State sources from yaml of from general knowledge.
#  Format the response in .html format.
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Eta Requirements</title>
# </head>
# <body>
# <h1>Fan Eta Requirement</h1>
# <p>Logical component <strong>Fan</strong> shall deliver η = 0.85 producing the fan‑air mass‑flow that generates bypass thrust for the engine.</p>
# <p><em>Source: YAML model (Fan logical component) and general aerospace propulsion knowledge.</em></p>
# <h1>HP Compressor Eta</h1>
# <p>Logical component <strong>HP Compressor</strong> shall deliver η = 0.90 producing high‑pressure air for the HP turbine inlet.</p>
# <p><em>Source: YAML model (HP Compressor logical component) and standard compressor efficiency data.</em></p>
# <h1>LP Compressor Eta</h1>
# <p>Logical component <strong>LP Compressor</strong> shall deliver η = 0.88 producing the intermediate‑pressure air that feeds the HP compressor.</p>
# <p><em>Source: YAML model (LP Compressor logical component) and typical low‑pressure compressor performance figures.</em></p>
# <h1>HP Turbine Eta</h1>
# <p>Logical component <strong>HP Turbine</strong> shall deliver η = 0.92 producing shaft torque that drives the HP shaft and ultimately the fan.</p>
# <p><em>Source: YAML model (HP Turbine logical component) and turbine efficiency references.</em></p>
# <h1>LP Turbine Eta</h1>
# <p>Logical component <strong>LP Turbine</strong> shall deliver η = 0.90 producing shaft torque that rotates the LP shaft and fan.</p>
# <p><em>Source: YAML model (LP Turbine logical component) and common low‑pressure turbine efficiency values.</em></p>
# <h1>Fuel Meter Valve Eta</h1>
# <p>Logical component <strong>Fuel Meter Valve (FMV)</strong> shall deliver η = 0.95 producing a precisely metered fuel flow to the combustion chamber.</p>
# <p><em>Source: YAML model (Fuel Meter Valve logical component) and fuel‑metering valve performance literature.</em></p>
# </body>
# </html>
# **Token Usage Info:**
#
# Tokens used: prompt=68651, completion=752, total=69403

# %%
import os
from openai import OpenAI
from IPython.core.display import HTML
from IPython.display import display, clear_output, Markdown
from capella_tools  import Open_AI_RAG_manager
  

analyzer.add_text_file_to_messages("Demo_TwinComp_Fuel.txt")



analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# ✅ File `Demo_TwinComp_Fuel.txt` added to messages for analysis.
# **Your prompt:**
# Generate a set of requirements for eta, use the attached notebook file for the values for eta for component. Use the yaml file for the names of component in the requirement.
# - Each requirment should be a pair: (name, body).
# - The name shall be five or fewer words introducing the requirement.
# - The body shall be in the format of a shall statement, that is clear and concise.
# - The  body shall refer to the the owning logical component. In format of component x shall deliver eta (use the greek symbol) y producing output z. Embelish the basic functions to improve readability and understanding.
# - Display name as html h1 header level.
# - Display the body as a html p for paragraph.
# - State sources from yaml of from general knowledge.
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Eta Requirements</title>
# </head>
# <body>
# <h1>Fan Efficiency Requirement</h1>
# <p>Logical component <strong>Fan</strong> shall deliver η = 0.92 producing the high‑velocity fan air that generates bypass thrust for the engine.</p>
# <p><em>Source: Demo_TwinComp_Fuel.txt (η_fan) and YAML model (Fan) plus general aerospace propulsion knowledge.</em></p>
# <h1>LP Compressor Efficiency</h1>
# <p>Logical component <strong>LP Compressor</strong> shall deliver η = 0.89 producing the intermediate‑pressure air that feeds the high‑pressure compressor.</p>
# <p><em>Source: Demo_TwinComp_Fuel.txt (η_lpc) and YAML model (LP Compressor) plus standard compressor performance data.</em></p>
# <h1>HP Compressor Efficiency</h1>
# <p>Logical component <strong>HP Compressor</strong> shall deliver η = 0.89 producing the high‑pressure air required at the HP turbine inlet.</p>
# <p><em>Source: Demo_TwinComp_Fuel.txt (η_hpc) and YAML model (HP Compressor) plus typical high‑pressure compressor efficiency references.</em></p>
# <h1>Combustion Chamber Efficiency</h1>
# <p>Logical component <strong>Compustion chamber</strong> shall deliver η = 0.965 producing the fully burned high‑energy gases for turbine expansion.</p>
# <p><em>Source: Demo_TwinComp_Fuel.txt (η_comb) and YAML model (Compustion chamber) plus combustion efficiency literature.</em></p>
# <h1>Engine Inlet Efficiency</h1>
# <p>Logical component <strong>LP Compress Inlet</strong> shall deliver η = 0.998 producing the clean, low‑loss airflow that enters the compressor train.</p>
# <p><em>Source: Demo_TwinComp_Fuel.txt (η_inlet) and YAML model (LP Compress Inlet) plus general inlet‑loss theory.</em></p>
# <h1>HP Turbine Efficiency</h1>
# <p>Logical component <strong>HP Turbine</strong> shall deliver η = 0.89 producing shaft torque that drives the HP shaft and ultimately the fan.</p>
# <p><em>Source: Demo_TwinComp_Fuel.txt (η_hpt) and YAML model (HP Turbine) plus turbine efficiency standards.</em></p>
# <h1>LP Turbine Efficiency</h1>
# <p>Logical component <strong>LP Turbine</strong> shall deliver η = 0.89 producing shaft torque that rotates the LP shaft and fan.</p>
# <p><em>Source: Demo_TwinComp_Fuel.txt (η_lpt) and YAML model (LP Turbine) plus low‑pressure turbine performance data.</em></p>
# <h1>Fan Nozzle Efficiency</h1>
# <p>Logical component <strong>Fan Nozzle</strong> shall deliver η = 1.00 producing the exhaust jet that converts fan air momentum into thrust.</p>
# <p><em>Source: Demo_TwinComp_Fuel.txt (η_noz) and YAML model (Fan Nozzle) plus nozzle‑flow theory.</em></p>
# </body>
# </html>
# **Token Usage Info:**
#
# Tokens used: prompt=69516, completion=1631, total=71147

# %%
print("Done")
# Out:
# Done

# %% [markdown]
# #
