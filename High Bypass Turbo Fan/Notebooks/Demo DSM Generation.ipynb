# %% [markdown]
# # DSM Generation
#
# Generation of DSM for High Bypass Turbo Fan

# %% [markdown]
# ### Model-Specific Code (Do Not Modify)
#
# This section contains code that is specific to the system model. It is updated only when the model is changed and should not require user modifications under normal circumstances.
#
# If a new model is introduced, ensure this section is reviewed and updated as needed.

# %%
#!pip install --upgrade git+https://github.com/tkSDISW/Capella_Tools 
import capellambse.decl

from capella_tools import capellambse_helper


from IPython import display as diag_display
resources = {
    "HBTurboFan": "HBTurbFan/High Bypass Turbo Fan",
}
path_to_model = "../High Bypass Turbo Fan.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources)

# %%
from capella_tools  import capella_embeddings_manager

# Generate embeddings for all objects
model_embedding_manager = capella_embeddings_manager.EmbeddingManager()

embedding_file = "embeddings.json" 
model_embedding_manager.set_files( path_to_model , embedding_file)

model_embedding_manager.create_model_embeddings(model)
# Out:
# ✅ EmbeddingManager initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: Default
# 🤖 Model: gpt-4o
# Loading embeddings
# embeddings loaded.

# %%
selected_objects = model_embedding_manager.query_and_select_top_objects("High Bypass Turbo Fan Logical Component", top_n=1)
# Out:
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: High Bypass Turbo Fan, Similarity: 0.88, Type: LogicalComponent, Phase: Logical Architecture LA, Source: , Target:

# %%
#Workflow
from capella_tools import capellambse_yaml_manager
yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects : 
    yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  



#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()

# %%
from capella_tools  import N2DiagramGenerator
# Example: Using the class with YAML content and a diagram name
with open("capella_model.yaml", "r") as f:
    yaml_content = f.read()

n2 = N2DiagramGenerator.N2DiagramGenerator(yaml_content, "LAB TURBO FAN",mode="functional" )
n2.run_all()


n2 = N2DiagramGenerator.N2DiagramGenerator(yaml_content, "LAB TURBO FAN",mode="component")
n2.run_all()
# Out:
# Excel file saved to LAB_TURBO_FAN_n2.xlsx
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Accept TLA</th>
#       <th>Adjust Vanes</th>
#       <th>Burn Fuel</th>
#       <th>Channel Air to HPC</th>
#       <th>Channel Bleed Air</th>
#       <th>Channel Fan Air to Turbine</th>
#       <th>Channel HP Outlet Air</th>
#       <th>Channel to LP Turbine</th>
#       <th>Compres LP Air</th>
#       <th>Compress Air</th>
#       <th>Contribut to Compession</th>
#       <th>Contribut to LP Compression</th>
#       <th>Control Engine</th>
#       <th>Control Fuel Flow</th>
#       <th>Deliver Thrust</th>
#       <th>Direct Hot Gas to Turbine</th>
#       <th>Direct Turbine Exhaust</th>
#       <th>Drive Fan and LP Compressor</th>
#       <th>Expel Bypass AIr</th>
#       <th>Extract Energy</th>
#       <th>Increase Air Mass Flow</th>
#       <th>Meassure LP DIscharge Pressure</th>
#       <th>Measure  Exhaust Gas Temp</th>
#       <th>Measure Bleed Air Valve Poistion</th>
#       <th>Measure HP Outlet Pressure</th>
#       <th>Measure Inlet Air Temperatur</th>
#       <th>Measure N1 Speed</th>
#       <th>Measure N2</th>
#       <th>Measure Position</th>
#       <th>Measure Pressure</th>
#       <th>Measure Turbine Outlet Pressure</th>
#       <th>Measure inlet Temperature (T2)</th>
#       <th>Move LP Stator Vanes</th>
#       <th>Provide Support Transfer Thrust</th>
#       <th>Receive Air</th>
#       <th>Receive Engine Cowling Thrust</th>
#       <th>Receive Nozzle Thrust</th>
#       <th>Rotate Fan and LP Compressor</th>
#       <th>Sense HP Stator Vane Position</th>
#       <th>Sense Position</th>
#       <th>Set Bleed Air Postion</th>
#       <th>Tranfer Torque</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Accept TLA</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Adjust Vanes</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Burn Fuel</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Channel Air to HPC</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Channel Bleed Air</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Channel Fan Air to Turbine</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Channel HP Outlet Air</th>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Channel to LP Turbine</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Compres LP Air</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></t
# HTML file saved to LAB_TURBO_FAN_n2.html
# Excel file saved to LAB_TURBO_FAN_n2.xlsx
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Bleed Air Valve Actuator</th>
#       <th>Bleed Air Valve Position</th>
#       <th>Bleed Air Vlave</th>
#       <th>Combustion Chamber Pressure (P4)</th>
#       <th>Combustion Outlet</th>
#       <th>Compustion chamber</th>
#       <th>Control System</th>
#       <th>Core Nozzle</th>
#       <th>Engine Cowling</th>
#       <th>Exhaust Gas Temperature (EGT)</th>
#       <th>FMV Position Sensor</th>
#       <th>Fan</th>
#       <th>Fan Inlet Temperature</th>
#       <th>Fan Nozzle</th>
#       <th>Fuel Meter Valve (FMV)</th>
#       <th>HP Compressor</th>
#       <th>HP Compressor Outlet Pressure (P3)</th>
#       <th>HP Shaft</th>
#       <th>HP Stator Vane Actuator</th>
#       <th>HP Stator Vane Position Sensor</th>
#       <th>HP Stator Vanes</th>
#       <th>HP Turbine</th>
#       <th>HP Turbine Inlet</th>
#       <th>HP Turbine Outlet</th>
#       <th>HP Turbine Outlet Pressure Sensor (4.5)</th>
#       <th>HPC Outlet</th>
#       <th>LP Compress Inlet</th>
#       <th>LP Compressor</th>
#       <th>LP Compressor discharge pressure (P2.5)</th>
#       <th>LP Stator Vanes</th>
#       <th>LP Stator Vanes Actuator</th>
#       <th>LP Turbine</th>
#       <th>LP and Fan Shaft</th>
#       <th>N1 Speed</th>
#       <th>N2 Senor</th>
#       <th>Nacelle</th>
#       <th>Stator Vane Position Sensor</th>
#       <th>Throttle Lever Angle</th>
#       <th>Turbine Intet Temperature (P2)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Bleed Air Valve Actuator</th>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Bleed Air Valve Position</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Bleed Air Vlave</th>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Combustion Chamber Pressure (P4)</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Combustion Outlet</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Compustion chamber</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Control System</th>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Core Nozzle</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Engine Cowling</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Exhaust Gas Temperature (EGT)</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
# HTML file saved to LAB_TURBO_FAN_n2.html

# %%
for object in  selected_objects : 
    obj = model.by_uuid(object["uuid"])
    for object in  obj.components :
        capellambse_helper.display_context_diagram(object)
# Out:
# <Diagram 'Context of Fan'>
# <Diagram 'Context of Nacelle'>
# <Diagram 'Context of LP Compressor'>
# <Diagram 'Context of HP Compressor'>
# <Diagram 'Context of Compustion chamber'>
# <Diagram 'Context of Fan Nozzle'>
# <Diagram 'Context of HP Turbine'>
# <Diagram 'Context of LP Turbine'>
# <Diagram 'Context of Core Nozzle'>
# <Diagram 'Context of Control System'>
# <Diagram 'Context of Turbine Intet Temperature (P2)'>
# <Diagram 'Context of Fan Inlet Temperature'>
# <Diagram 'Context of LP Compress Inlet '>
# <Diagram 'Context of HP Turbine Inlet'>
# <Diagram 'Context of LP Compressor discharge pressure (P2.5)'>
# <Diagram 'Context of HPC Outlet'>
# <Diagram 'Context of HP Compressor Outlet Pressure (P3)'>
# <Diagram 'Context of HP Stator Vanes'>
# <Diagram 'Context of LP Stator Vanes'>
# <Diagram 'Context of HP Stator Vane Actuator'>
# <Diagram 'Context of Combustion Outlet'>
# <Diagram 'Context of Fuel Meter Valve (FMV)'>
# <Diagram 'Context of HP Turbine Outlet Pressure Sensor (4.5)'>
# <Diagram 'Context of HP Turbine Outlet'>
# <Diagram 'Context of LP and Fan Shaft'>
# <Diagram 'Context of HP Shaft'>
# <Diagram 'Context of Combustion Chamber Pressure (P4)'>
# <Diagram 'Context of Exhaust Gas Temperature (EGT)'>
# <Diagram 'Context of N2 Senor'>
# <Diagram 'Context of N1 Speed'>
# <Diagram 'Context of FMV Position Sensor'>
# <Diagram 'Context of Throttle Lever Angle'>
# <Diagram 'Context of Bleed Air Valve Actuator'>
# <Diagram 'Context of Stator Vane Position Sensor'>
# <Diagram 'Context of LP Stator Vanes Actuator'>
# <Diagram 'Context of Bleed Air Valve Position'>
# <Diagram 'Context of Bleed Air Vlave'>
# <Diagram 'Context of HP Stator Vane Position Sensor'>
# <Diagram 'Context of Engine Cowling'>

# %% [markdown]
# ## 💬 Predefined Prompts for Analysis
#
# ### Purpose
# This cell contains predefined prompts for analyzing different types of ARCADIA elements, including components, functions, operational processes, and a default prompt. You can use these as-is or tailor them to suit your specific needs.
#
#
# ### Instructions
# 1. The appropriate prompt will be used for your analysis needs.
# 2. Modify the prompt to include additional details or requirements, if necessary.
#
# ### Notes
# - Predefined prompts are designed to guide analysis and ensure consistency.
# - Tailoring the prompts allows you to focus on specific aspects of the model relevant to your use case.
#
# > 💡 **Tip:** Save your tailored prompts for reuse in similar analyses or workflows.

# %%
print("Done")
# Out:
# Done

# %% [markdown]
# #
